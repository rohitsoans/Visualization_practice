# %%
import pandas as pd

# %%
import os

# %%
os.getcwd() # okay so this is my working directory
# Out:
# 'C:\\Users\\Rohit'

# %%
movies = pd.read_csv("Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
len(movies.columns)
# Out:
# 6

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.head(0)
# Out:
# Empty DataFrame
# Columns: [Film, Genre, CriticRating, AudienceRating, BudgetMillions, Year]
# Index: []

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null object
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
#year is also an integer here

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
#we want to create categorical variables because Films and year are actually categories

# %%
movies['Film'][:4]
# Out:
# 0    (500) Days of Summer
# 1              10,000 B.C.
# 2               12 Rounds
# 3                127 Hours
# Name: Film, dtype: object

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null object
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre=movies.Genre.astype('category')

# %%
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
#to get unique values

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe() #now no year mentioned
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#joint plot #chart 1

# %%
j=sns.jointplot(data=movies, x='CriticRating', y='AudienceRating',kind="hex")

# %%
# we can see from the JP that the audience is slightly more loose

# %% [markdown]
# _________

# %%
#histograms

# %%
m1=sns.distplot(movies.AudienceRating, bins=30)

# %%
m2=sns.distplot(movies.CriticRating)

# %%
n1=plt.hist(movies.AudienceRating, bins=15) #press tab while writing aud... for it to autocomplete

# %%
#chart 2

# %%
n1=plt.hist(movies.AudienceRating, bins=15) #press tab while writing aud... for it to autocomplete
sns.set_style("darkgrid")

# %%
#chart 3

# %%
#stacked histograms

# %%
h1=plt.hist(movies.BudgetMillions)

# %%
movies[movies.Genre=='Drama'].BudgetMillions
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
movies[movies.Genre=='Drama']
# Out:
#                                     Film  Genre  CriticRating  AudienceRating  \
# 10                            88 Minutes  Drama             5              51
# 11                    A Dangerous Method  Drama            79              89
# 13                        A Serious Man   Drama            89              64
# 18                          Albert Nobbs  Drama            53              43
# 23                       All Good Things  Drama            33              64
# 26                          An Education  Drama            94              78
# 27                             Anonymous  Drama            46              66
# 47                    Black Swan          Drama            88              86
# 53                             Brothers   Drama            61              62
# 55                                Buried  Drama            86              63
# 56                             Burlesque  Drama            36              66
# ...

# %%
h1=plt.hist(movies[movies.Genre=='Drama'].BudgetMillions) # i simply put the filtered part in brackets

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions, bins=20)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions ,bins=20)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions, bins=20)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
movies[movies.Genre=='Drama'].BudgetMillions])
plt.show() # I first ran the Action and Drama filter.
#then i made it a list by puting sq bracket around
#only then did i add the histogram function
#thus graphs do only lists

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,
movies[movies.Genre=='Drama'].BudgetMillions], bins=20, stacked=True)
plt.show()
#stacked

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=[] #empty list or list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    print(list1)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# 52      17
# 58     140
# 60      85
# 63      40
# 66     125
# 67      25
# 69      40
# 70      90
# 73      30
# 76     163
# 77      13
# 81      25
# 83      20
# 86      45
# 94      30
# 98      33
# 101     75
# 102     30
# 106     45
#       ...
# 433    138
# 435     50
# 439     40
# 441     80
# 443    150
# 448     25
# 451     40
# 454    145
# 458    100
# 472    150
# 473      6
# 474      0
# 477    100
# 479     75
# 493    150
# 495     35
# 499    150
# 500    195
# 501    210
# 502     30
# 504    170
# 512     35
# 514     95
# 528     75
# 530     25
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64]
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
# 33     237
# 36      45
# 39      45
# 40      70
# 45     150
# 49      68
# ...

# %%
h=plt.hist(list1, bins=20, stacked=True)

# %%
h=plt.hist(list1, bins=20, stacked=True,rwidth=1) #to remove the white gaps in between

# %%
#add the legend

# %%
mylabels=list()
for gen in movies.Genre.cat.categories:
    mylabels.append(gen)

h=plt.hist(list1, bins=20, stacked=True,rwidth=1,label=mylabels) #to remove the white gaps in between
plt.legend()

# %%
#KDE plot

# %%
vis1=sns.lmplot(data=movies, x='CriticRating',y='AudienceRating', fit_reg=False,hue='Genre',
                size=7,aspect=1)

# %%
k1=sns.kdeplot(movies.CriticRating,movies.AudienceRating)

# %%
#the smallest circle(kernel) is the most dense area. everything speads out from there.
#

# %%
k1=sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade =True)

# %%
k1=sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade =True, shade_lowest=False) #to see the grid

# %%
k1=sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade =True, shade_lowest=False, cmap='Reds')#color red

# %%
# to remove roughness on edges
k1=sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade =True, shade_lowest=False, cmap='Reds')
k1b=sns.kdeplot(movies.CriticRating,movies.AudienceRating, cmap='Reds')

# %%
#working with subplots

# %%
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)
sns.set_style("dark")

# %%
k1=sns.kdeplot(movies.BudgetMillions, movies.CriticRating)
sns.set_style("dark") # in reality doesnt go below 0

# %%
f, axes= plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating)#f is evreything. Axes is very specific arrays. 
#if it was two dimensional (Eg 2*2, then the array will be like axes[2,2])

# %%
f, axes= plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating)#f is evreything. Axes is very specific arrays. 
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
f, axes= plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating)#f is evreything. Axes is very specific arrays. 
k2.set(xlim=(-20,200))
# Out:
# [(-20, 200)]

# %%
#or
f, axes= plt.subplots(1,2,figsize=(12,6), sharex=True)
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])#f is evreything. Axes is very specific arrays. 
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
f, axes= plt.subplots(1,2,figsize=(12,6), sharex=True, sharey=True)
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])#f is evreything. Axes is very specific arrays. 
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
#now easier to compare

# %%
#ViolinPlots

# %%
w=sns.boxplot(data=movies, x='Genre', y='CriticRating')# since it is median based, outliers are excluded

# %%
z=sns.violinplot(data=movies, x='Genre', y='CriticRating')#it shows distribution in the width

# %%
wz=sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
wz=sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating')

# %%
#create facet grid

# %%
g=sns.FacetGrid(movies, row='Genre', hue='Genre')

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')

# %%
#you can populate using any chart

# %%
g=sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillions')

# %%
#back to scatter plot:#Facet shows how things evolved
g=sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)

# %%
#Controlling axes and Adding diagonals
g=sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100), ylim=(0,100))

# %%
#now we will put a diagonal #shows overtime data. and data over the line shows that audiance gave better ratings.....
g=sns.FacetGrid(movies, row='Genre', col='Year',hue='Genre')
kws=dict(s=50,linewidth=0.5,edgecolor='black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**kws)
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:#it is an array of all the facet grids
    ax.plot((0,100),(0,100),c="gray",ls="--")
g.add_legend()

# %%
#chart 5

# %%
#creating dashboards

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2, figsize=(15,15))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1])
z=sns.violinplot(data=movies, x='Genre', y='CriticRating',ax=axes[1,0])
k3=sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade =True, shade_lowest=False, cmap='Reds',ax=axes[1,1])

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2, figsize=(15,15))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1])
z=sns.violinplot(data=movies, x='Genre', y='CriticRating',ax=axes[1,0])
n1=axes[1,1].hist(movies.AudienceRating, bins=15)#how to put a plt graph in this
plt.show()

# %%
[k1]

# %%
sns.set_style('dark', {"axes.facecolor":"black"})
f,axes=plt.subplots(2,2, figsize=(15,15))
k1=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,0], shade=True, shade_lowest=True,cmap="inferno")
k1b=sns.kdeplot(movies.BudgetMillions, movies.AudienceRating,ax=axes[0,0],cmap="cool")


k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1], shade=True, shade_lowest=True,cmap="inferno")
k2=sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1],cmap="cool")


z=sns.violinplot(data=movies, x='Year', y='BudgetMillions',ax=axes[1,0], palette='YlOrRd')


k3=sns.kdeplot(movies.CriticRating,movies.AudienceRating, shade =True, shade_lowest=False, cmap='gist_gray_r',ax=axes[1,1])

# %%
movies[movies.Genre=='Drama']
# Out:
#                                     Film  Genre  CriticRating  AudienceRating  \
# 10                            88 Minutes  Drama             5              51
# 11                    A Dangerous Method  Drama            79              89
# 13                        A Serious Man   Drama            89              64
# 18                          Albert Nobbs  Drama            53              43
# 23                       All Good Things  Drama            33              64
# 26                          An Education  Drama            94              78
# 27                             Anonymous  Drama            46              66
# 47                    Black Swan          Drama            88              86
# 53                             Brothers   Drama            61              62
# 55                                Buried  Drama            86              63
# 56                             Burlesque  Drama            36              66
# ...

# %%
#thematic finishing touches

# %%
mylabels=list()
for gen in movies.Genre.cat.categories:
    mylabels.append(gen)

sns.set_style("whitegrid")
h=plt.hist(list1, bins=20, stacked=True,rwidth=1,label=mylabels) #to remove the white gaps in between
plt.legend()

# %%
mylabels=list()
for gen in movies.Genre.cat.categories:
    mylabels.append(gen)

fig,ax=plt.subplots() #easyhack to control size of figure
fig.set_size_inches(11.7,8.27)
h=plt.hist(list1, bins=20, stacked=True,rwidth=1,label=mylabels) #to remove the white gaps in between
plt.title("Movie Budget Distribution", fontsize=35, color="DarkBlue", fontname="Impact")

plt.xticks(fontsize=20, color= "Gray")
plt.yticks(fontsize=20, color="Blue")
plt.ylabel("Number of Movies", fontsize=25, color= "Red")
plt.xlabel("Budget", fontsize=25, color= "Green")
plt.legend(frameon=True, fancybox=True, shadow=True,framealpha=0.20,prop={'size':20})
